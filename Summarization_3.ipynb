# %%
# wrap the output in colab cells
from IPython.display import HTML, display

def set_css():
  display(HTML('''

  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# install transformers with sentencepiece
# !pip install transformers[sentencepiece]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Full path to the text file on Google Drive
text_file_path = '/content/drive/MyDrive/MyFiles/Chopin Complete Stories.txt'

# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title= Chopin Complete Stories.txt'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('Chopin Complete Stories.txt')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-5-1b544f38a177> in <cell line: 15>()
#      13
#      14 # Copy/download the file
# ---> 15 fid = drive.ListFile({'q':"title= Chopin Complete Stories.txt'"}).GetList()[0]['id']
#      16 f = drive.CreateFile({'id': fid})
#      17 f.GetContentFile('Chopin Complete Stories.txt')
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in GetList(self)
#     160       self['maxResults'] = 1000
#     161       result = []
# --> 162       for x in self:
#     163         result.extend(x)
#     164       del self['maxResults']
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in __next__(self)
#     144     if 'pageToken' in self and self['pageToken'] is None:
#     145       raise StopIteration
# --> 146     result = self._GetList()
#     147     self['pageToken'] = self.metadata.get('nextPageToken')
# ...

# %%
# Specify the file name
file_name = 'Chopin Complete Stories.txt'

# Search for the file in Google Drive
file_list = drive.ListFile({'q': f"title='{file_name}'"}).GetList()

# Get the file ID
if file_list:
    file_id = file_list[0]['id']
    print(f"File ID for {file_name}: {file_id}")
else:
    print(f"File {file_name} not found.")
# Out:
# File ID for Chopin Complete Stories.txt: 135wGqSaR38P7I6xTMd7L0mv3rFCtdlpM

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Full path to the text file on Google Drive
text_file_path = '/content/drive/MyDrive/MyFiles/Chopin Complete Stories.txt'

# %%
# !pip install hyperas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.1 MB/s eta 0:00:00
# ...

# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title= Chopin Complete Stories.txt'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('Chopin Complete Stories.txt')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-10-1b544f38a177> in <cell line: 15>()
#      13
#      14 # Copy/download the file
# ---> 15 fid = drive.ListFile({'q':"title= Chopin Complete Stories.txt'"}).GetList()[0]['id']
#      16 f = drive.CreateFile({'id': fid})
#      17 f.GetContentFile('Chopin Complete Stories.txt')
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in GetList(self)
#     160       self['maxResults'] = 1000
#     161       result = []
# --> 162       for x in self:
#     163         result.extend(x)
#     164       del self['maxResults']
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in __next__(self)
#     144     if 'pageToken' in self and self['pageToken'] is None:
#     145       raise StopIteration
# --> 146     result = self._GetList()
# ...

# %%
# Specify the file name
file_name = 'Chopin Complete Stories.txt'

# Search for the file in Google Drive
file_list = drive.ListFile({'q': f"title='{file_name}' in parents"}).GetList()

# Get the file ID
if file_list:
    file_id = file_list[0]['id']
    print(f"File ID for {file_name}: {file_id}")
else:
    print(f"File {file_name} not found.")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-11-6bf55859ff77> in <cell line: 5>()
#       3
#       4 # Search for the file in Google Drive
# ----> 5 file_list = drive.ListFile({'q': f"title='{file_name}' in parents"}).GetList()
#       6
#       7 # Get the file ID
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in GetList(self)
#     160       self['maxResults'] = 1000
#     161       result = []
# --> 162       for x in self:
#     163         result.extend(x)
#     164       del self['maxResults']
#
# /usr/local/lib/python3.10/dist-packages/pydrive/apiattr.py in __next__(self)
#     144     if 'pageToken' in self and self['pageToken'] is None:
#     145       raise StopIteration
# --> 146     result = self._GetList()
#     147     self['pageToken'] = self.metadata.get('nextPageToken')
#     148     return result
#
# ...

# %%
# Specify the file name
file_name = 'Chopin Complete Stories.txt'

# Search for the file in Google Drive
file_list = drive.ListFile({'q': f"title='{file_name}'"}).GetList()

# Get the file ID
if file_list:
    file_id = file_list[0]['id']
    print(f"File ID for {file_name}: {file_id}")
else:
    print(f"File {file_name} not found.")
# Out:
# File ID for Chopin Complete Stories.txt: 135wGqSaR38P7I6xTMd7L0mv3rFCtdlpM

# %%
q = "title='Chopin Complete Stories.txt'"

# %%
# Copy/download the file
file_list = drive.ListFile({'q': "title='Chopin Complete Stories.txt'"}).GetList()
if file_list:
    fid = file_list[0]['id']
    f = drive.CreateFile({'id': fid})
    f.GetContentFile('Chopin Complete Stories.txt')
    print('File downloaded successfully!')
else:
    print('File not found in Google Drive.')
# Out:
# File downloaded successfully!

# %%
# Assuming you've successfully downloaded the file
with open('Chopin Complete Stories.txt', 'r') as file:
    file_content = file.read()

# Now you can use the variable file_content
print(file_content)
# Out:
#                            A Night in Acadie
#
#
# There was nothing to do on the plantation so Telèsphore, having a few
# dollars in his pocket, thought he would go down and spend Sunday in the
# vicinity of Marksville.
#
# There was really nothing more to do in the vicinity of Marksville than
# in the neighborhood of his own small farm; but Elvina would not be down
# there, nor Amaranthe, nor any of Ma’me Valtour’s daughters to harass him
# with doubt, to torture him with indecision, to turn his very soul into a
# weather-cock for love’s fair winds to play with.
#
# Telèsphore at twenty-eight had long felt the need of a wife. His home
# without one was like an empty temple in which there is no altar, no
# offering. So keenly did he realize the necessity that a dozen times at
# least during the past year he had been on the point of proposing
# marriage to almost as many different young women of the neighborhood.
# ...

# %%
sentences = nltk.sent_tokenize("Chopin Complete Stories")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3aa01e26fe17> in <cell line: 1>()
# ----> 1 sentences = nltk.sent_tokenize("Chopin Complete Stories")
#
# NameError: name 'nltk' is not defined

# %%
import nltk
nltk.download('punkt')

# Assuming text_content is your variable with text data
sentences = nltk.sent_tokenize("Chopin complete Stories")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Assuming you've successfully downloaded the file and read its content
with open('Chopin Complete Stories.txt', 'r') as file:
    file_content = file.read()

# Calculate the total number of characters
total_characters = len(file_content)

# Print the result
print(f'Total characters in the file: {total_characters}')
# Out:
# Total characters in the file: 1387014

# %%
# import and initialize the tokenizer and model from the checkpoint
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

checkpoint = "sshleifer/distilbart-cnn-12-6"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]

# %%
# max tokens including the special tokens
tokenizer.model_max_length
# Out:
# 1024

# %%
# number of special tokens
tokenizer.num_special_tokens_to_add()
# Out:
# 2

# %%
sentences = nltk.sent_tokenize("Chopin Complete Stories")

# %%
sentences = nltk.sent_tokenize("Chopin Complete Stories")

# %%
import nltk
nltk.download('punkt')

# Assuming FileContent is your text data
sentences = nltk.sent_tokenize("Chopin Complete Stories")

# Now you can iterate over the sentences
chunks = []
count = -1

for sentence in sentences:
    count += 1
    combined_length = len(tokenizer.tokenize(sentence)) + length
    # Rest of your code...
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# initialize
length = 0
chunk = ""
chunks = []
count = -1
for sentence in sentences:
  count += 1
  combined_length = len(tokenizer.tokenize(sentence)) + length # add the no. of sentence tokens to the length counter

  if combined_length  <= tokenizer.max_len_single_sentence: # if it doesn't exceed
    chunk += sentence + " " # add the sentence to the chunk
    length = combined_length # update the length counter

    # if it is the last sentence
    if count == len(sentences) - 1:
      chunks.append(chunk.strip()) # save the chunk

  else:
    chunks.append(chunk.strip()) # save the chunk

    # reset
    length = 0
    chunk = ""

    # take care of the overflow sentence
    chunk += sentence + " "
    length = len(tokenizer.tokenize(sentence))
len(chunks)
# Out:
# 1

# %%
[len(tokenizer.tokenize(c)) for c in chunks]
# Out:
# [5]

# %%
sum([len(tokenizer(c).input_ids) for c in chunks])
# Out:
# 7

# %%
# inputs to the model
inputs = [tokenizer(chunk, return_tensors="pt") for chunk in chunks]

# %%
for input in inputs:
  output = model.generate(**input)
  print(tokenizer.decode(*output, skip_special_tokens=True))
# Out:
#  Chopin Complete Stories is published by Chopin, published in New York, New York and Washington, DC, based on Chopin's book, "Chopin" Chopin: "I am a great writer. I love Chopin. I am so proud of Chopin," he said.

# %%
# find the max tokens in the longest sentence
max([len(tokenizer.tokenize(sentence)) for sentence in sentences])
# Out:
# 5

# %%
for input in inputs:
  output = model.generate(**input)
  print(tokenizer.decode(*output, skip_special_tokens=True))
# Out:
#  Chopin Complete Stories is published by Chopin, published in New York, New York and Washington, DC, based on Chopin's book, "Chopin" Chopin: "I am a great writer. I love Chopin. I am so proud of Chopin," he said.

# %%
# Assuming you've successfully downloaded the file
with open('Chopin Complete Stories.txt', 'r') as file:
    file_content = file.read()

# Now you can use the variable file_content
print(file_content)
# Out:
#                            A Night in Acadie
#
#
# There was nothing to do on the plantation so Telèsphore, having a few
# dollars in his pocket, thought he would go down and spend Sunday in the
# vicinity of Marksville.
#
# There was really nothing more to do in the vicinity of Marksville than
# in the neighborhood of his own small farm; but Elvina would not be down
# there, nor Amaranthe, nor any of Ma’me Valtour’s daughters to harass him
# with doubt, to torture him with indecision, to turn his very soul into a
# weather-cock for love’s fair winds to play with.
#
# Telèsphore at twenty-eight had long felt the need of a wife. His home
# without one was like an empty temple in which there is no altar, no
# offering. So keenly did he realize the necessity that a dozen times at
# least during the past year he had been on the point of proposing
# marriage to almost as many different young women of the neighborhood.
# ...

# %%
# Assuming you've successfully downloaded the file and read its content
with open('Chopin Complete Stories.txt', 'r') as file:
    file_content = file.read()

# Calculate the total number of characters
total_characters = len(file_content)

# Print the result
print(f'Total characters in the file: {total_characters}')
# Out:
# Total characters in the file: 1387014

# %%
# import and initialize the tokenizer and model from the checkpoint
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

checkpoint = "sshleifer/distilbart-cnn-12-6"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)

# %%
tokenizer.model_max_length
# Out:
# 1024

# %%
# number of special tokens
tokenizer.num_special_tokens_to_add()
# Out:
# 2

# %%
sentences = nltk.sent_tokenize("Chopin Complete Stories")

# %%
import nltk
nltk.download('punkt')

# Assuming FileContent is your text data
sentences = nltk.sent_tokenize("Chopin Complete Stories")

# Now you can iterate over the sentences
chunks = []
count = -1

for sentence in sentences:
    count += 1
    combined_length = len(tokenizer.tokenize(sentence)) + length
    # Rest of your code...
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
